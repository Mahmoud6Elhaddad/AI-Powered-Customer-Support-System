# %%
import pandas as pd

df_ecom=pd.read_csv('faq_ecommerce.csv')
df_saas=pd.read_csv('faq_saas.csv')

# %%
df_combined = pd.concat([df_ecom, df_saas], ignore_index=True)
df_combined
# Out:
#       faq_id               domain category  \
# 0    FAQ-001  E-Commerce / Retail  billing
# 1    FAQ-002  E-Commerce / Retail  billing
# 2    FAQ-003  E-Commerce / Retail  billing
# 3    FAQ-004  E-Commerce / Retail  billing
# 4    FAQ-005  E-Commerce / Retail  billing
# ..       ...                  ...      ...
# 195  FAQ-096          SaaS / Tech  account
# 196  FAQ-097          SaaS / Tech  account
# 197  FAQ-098          SaaS / Tech  account
# 198  FAQ-099          SaaS / Tech  account
# 199  FAQ-100          SaaS / Tech  account
#
#                                             question  \
# 0                       How long does a refund take?
# 1             I was charged twice. What should I do?
# 2                Why was I charged after cancelling?
# 3    My promo code didn't apply. Can I still get it?
# 4                           How do I get an invoice?
# ..                                               ...
# 195                      How to enable login alerts?
# ...

# %%
df_combined.to_csv('faq.csv', index=False)
